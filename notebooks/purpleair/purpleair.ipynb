# %%
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow version: " + tf.__version__)

import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-8396be3b0154> in <module>
#       6 import seaborn as sns
#       7
# ----> 8 import tensorflow as tf
#       9
#      10 from tensorflow import keras
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/__init__.py in <module>
#      52 from ._api.v2 import autograph
#      53 from ._api.v2 import bitwise
# ---> 54 from ._api.v2 import compat
#      55 from ._api.v2 import config
#      56 from ._api.v2 import data
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v1/__init__.py in <module>
#      32 from . import autograph
#      33 from . import bitwise
# ---> 34 from . import compat
#      35 from . import config
#      36 from . import data
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v1/compat/__init__.py in <module>
#      38
#      39 from . import v1
# ---> 40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      42 from tensorflow.python.compat.compat import forward_compatible
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v1/compat/v2/__init__.py in <module>
#      30
#      31 from . import compat
# ---> 32 from tensorflow._api.v2.compat.v2 import __operators__
#      33 from tensorflow._api.v2.compat.v2 import audio
#      34 from tensorflow._api.v2.compat.v2 import autodiff
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v2/__init__.py in <module>
#      34 from . import autograph
#      35 from . import bitwise
# ---> 36 from . import compat
#      37 from . import config
#      38 from . import data
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v2/compat/__init__.py in <module>
#      38
#      39 from . import v1
# ---> 40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      42 from tensorflow.python.compat.compat import forward_compatible
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorflow/_api/v2/compat/v2/compat/v2/__init__.py in <module>
#     325 _current_module = _sys.modules[__name__]
#     326 try:
# --> 327   from tensorboard.summary._tf import summary
#     328   _current_module.__path__ = (
#     329       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorboard/summary/__init__.py in <module>
#      29 # Load the V2 summary API if accessible.
#      30 try:
# ---> 31     from tensorboard.summary import v2
#      32     from tensorboard.summary.v2 import *
#      33 except ImportError:
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorboard/summary/v2.py in <module>
#      22
#      23 # pylint: disable=unused-import
# ---> 24 from tensorboard.plugins.audio.summary_v2 import audio
#      25 from tensorboard.plugins.histogram.summary_v2 import histogram
#      26 from tensorboard.plugins.image.summary_v2 import image
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorboard/plugins/audio/summary_v2.py in <module>
#      28 import functools
#      29
# ---> 30 from tensorboard.compat import tf2 as tf
#      31 from tensorboard.plugins.audio import metadata
#      32 from tensorboard.util import lazy_tensor_creator
#
# ~/github/machine-learning-tf2-jupyter/pi/mlpi/lib/python3.8/site-packages/tensorboard/compat/__init__.py in <module>
#      29
#      30
# ---> 31 @_lazy.lazy_load("tensorboard.compat.tf")
#      32 def tf():
#      33     """Provide the root module of a TF-like API for use within TensorBoard.
#
# AttributeError: module 'tensorboard.lazy' has no attribute 'lazy_load'

# %%
dataset_path = keras.utils.get_file("purpleair.data", "https://uafbuenaire.azurewebsites.net/api/purpleair")
dataset_path
# Out:
# 'C:\\Users\\jonat\\.keras\\datasets\\purpleair.data'

# %%
raw_dataset = pd.read_json(dataset_path)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#         ID                 Label DEVICE_LOCATIONTYPE  THINGSPEAK_PRIMARY_ID  \
# 200  23792            Vide Way B                 NaN                 664008
# 201  28929     Willow Community              outside                 729844
# 202  28930   Willow Community  B                 NaN                 729846
# 203  22519    Woodcenter Busstop             outside                 653639
# 204  22520  Woodcenter Busstop B                 NaN                 653642
#
#     THINGSPEAK_PRIMARY_ID_READ_KEY  THINGSPEAK_SECONDARY_ID  \
# 200               DBKR8OJ1XYI9CRDO                   664009
# 201               AKPHAB4X79TBIL32                   729845
# 202               L00G67F0DUUI5QKZ                   729847
# 203               4FXAFO2PPDW1B6T6                   653641
# 204               Z133JISCIBNWCGFM                   653643
#
#     THINGSPEAK_SECONDARY_ID_READ_KEY        Lat         Lon  PM2_5Value  ...  \
# 200                 4ZYYGXEFBJC90TVI  64.904524 -147.730978        2.14  ...
# 201                 GF05H5EM8N6RBDHW  61.721425 -150.040968        1.37  ...
# 202                 MKHSYE2TQ0ORUELO  61.721425 -150.040968        1.12  ...
# 203                 WKB6MXU1GTU4XDXL  64.857714 -147.822528        3.34  ...
# 204                 U5YVN1XHRQ0NGVT0  64.857714 -147.822528        3.15  ...
#
#                        Type Hidden isOwner  humidity  temp_f  pressure  AGE  \
# 200                     NaN  false       0       NaN     NaN       NaN    1
# 201  PMS5003+PMS5003+BME280  false       0      41.0    68.0   1010.17    0
# 202                     NaN  false       0       NaN     NaN       NaN    0
# 203  PMS5003+PMS5003+BME280  false       0      46.0    70.0    998.00    0
# 204                     NaN  false       0       NaN     NaN       NaN    0
#
#                                                  Stats ParentID  Flag
# 200  {"v":2.14,"v1":2.98,"v2":3.3,"v3":3.43,"v4":3....  23791.0   NaN
# 201  {"v":1.37,"v1":1.19,"v2":1.39,"v3":1.48,"v4":1...      NaN   NaN
# 202  {"v":1.12,"v1":1.1,"v2":1.29,"v3":1.39,"v4":1....  28929.0   NaN
# 203  {"v":3.34,"v1":3.2,"v2":3.54,"v3":3.82,"v4":3....      NaN   NaN
# 204  {"v":3.15,"v1":3.7,"v2":4.1,"v3":4.35,"v4":4.2...  22519.0   NaN
#
# [5 rows x 21 columns]
